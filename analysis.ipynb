# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
rel_simple_ks = np.load('results/rel_simple_ks_vals.npy')
simple_ks = np.load('results/simple_ks_vals.npy')
gasf_ks = np.load('results/gasf_iter20_ks_vals.npy')

# %%
plt.plot(rel_simple_ks)
plt.plot(simple_ks)
plt.plot(gasf_ks)
