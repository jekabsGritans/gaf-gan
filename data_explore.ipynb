# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

prices = pd.read_csv('data/eurusd_minute.csv')['BidClose'].values

# %%
n = 17
arr = prices[32*n:32*(n+1)]
arr = np.diff(arr)
# side by side plots
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2)

ax1.plot(arr)
ax1.set_title('Price changes')
ax1.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:.0%}".format(x)))
ax3.plot((arr-arr.min())/(arr.max()-arr.min()))
ax3.set_title('Scaled and shifted price changes')
ax3.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:.0%}".format(x)))


cummulatives = np.cumprod(arr+1)
distorted_cummulatives = np.cumprod((arr-arr.min())/(arr.max()-arr.min())+1)
ax2.plot(cummulatives)
ax2.set_title('Original prices')
ax4.plot(distorted_cummulatives)
ax4.set_title('Distorted prices')

fig.set_size_inches(9,8)
plt.show()

# %%
log_prices = np.log(prices[1000:])
log_returns = np.diff(log_prices)
print(f"Mean: {log_returns.mean():.3f}, Std: {log_returns.std():.3f}, Max: {log_returns.max():.3f}, Min: {log_returns.min():.3f}")
plt.hist(log_returns, bins=200)
plt.show()
# Out:
# Mean: -0.000, Std: 0.000, Max: 0.017, Min: -0.015

# %%
plt.plot(log_prices)
plt.show()

# %%
changes = prices[1:]/prices[:-1] - 1
plt.plot(changes)
